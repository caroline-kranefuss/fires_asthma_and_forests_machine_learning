# %%
import pandas as pd

# %%
# Load the data
two = pd.read_csv('asthma_2022.txt')
three = pd.read_csv('asthma_2023.txt')
#five = 

# Look at a sample df 
two.head()
# Out:
#    2022 National Rankings Metropolitan Area  Total Score  \
# 0                       1        Detroit MI       100.00
# 1                       2      Cleveland OH        99.51
# 2                       3      Allentown PA        98.62
# 3                       4       Lakeland FL        97.72
# 4                       5         Fresno CA        91.36
#
#                                             Counties
# 0  Wayne County, Lapeer County, Livingston County...
# 1  Ashtabula County, Cuyahoga County, Geauga Coun...
# 2  Warren County NJ, Carbon County PA, Lehigh Cou...
# 3                                        Polk County
# 4                       Fresno County, Madera County

# %%
# Rename columns - doing individually due to year in columns

two = two.rename(columns={'2022 National Rankings': 'Rank',
                 'Metropolitan Area': 'Metropolitan_Area',
                 'Total Score': 'Score'})

three = three.rename(columns={'2023 National Rankings': 'Rank',
                 'Metropolitan Area': 'Metropolitan_Area',
                 'Total Score': 'Score'})

"""
five = five.rename(columns={'2025 National Rankings': 'Rank',
                 'Metropolitan Area': 'Metropolitan_Area',
                 'Total Score': 'Score'})
"""
# Out:
# "\nfive = five.rename(columns={'2025 National Rankings': 'Rank',\n                 'Metropolitan Area': 'Metropolitan_Area',\n                 'Total Score': 'Score'})\n"

# %%
# Make a state column - can be written as a function to be applied to each dataframe

def state(df):
    df['State'] = df['Metropolitan_Area'].str[-2:]
    return df

state(two)
state(three)
# state(five)
# Out:
#     Rank  Metropolitan_Area   Score  \
# 0      1       Allentown PA  100.00
# 1      2        Lakeland FL   93.65
# 2      3      Charleston SC   92.89
# 3      4       Cleveland OH   92.69
# 4      5         Detroit MI   91.48
# ..   ...                ...     ...
# 95    96          Durham NC   36.95
# 96    97         Madison WI   36.76
# 97    98          Oxnard CA   36.60
# 98    99  Salt Lake City UT   35.21
# 99   100           Provo UT   23.42
#
#                                              Counties State
# 0   Warren County NJ, Carbon County PA, Lehigh Cou...    PA
# 1                                         Polk County    FL
# 2   Berkeley County, Charleston County, Dorchester...    SC
# 3   Ashtabula County, Cuyahoga County, Geauga Coun...    OH
# 4   Wayne County, Lapeer County, Livingston County...    MI
# ..                                                ...   ...
# 95  Chatham County, Durham County, Orange County, ...    NC
# 96  Columbia County, Dane County, Green County, Io...    WI
# 97                                     Ventura County    CA
# 98                    Salt Lake County, Tooele County    UT
# 99                           Juab County, Utah County    UT
#
# [100 rows x 5 columns]

# %%
# Make each county entry a list

def counties_list(df):
    df['Counties'] =  df['Counties'].astype(str).str.split(', ')
    return df

counties_list(two)
counties_list(three)
# counties_list(five)
# Out:
#     Rank  Metropolitan_Area   Score  \
# 0      1       Allentown PA  100.00
# 1      2        Lakeland FL   93.65
# 2      3      Charleston SC   92.89
# 3      4       Cleveland OH   92.69
# 4      5         Detroit MI   91.48
# ..   ...                ...     ...
# 95    96          Durham NC   36.95
# 96    97         Madison WI   36.76
# 97    98          Oxnard CA   36.60
# 98    99  Salt Lake City UT   35.21
# 99   100           Provo UT   23.42
#
#                                              Counties State
# 0   [Warren County NJ, Carbon County PA, Lehigh Co...    PA
# 1                                       [Polk County]    FL
# 2   [Berkeley County, Charleston County, Dorcheste...    SC
# 3   [Ashtabula County, Cuyahoga County, Geauga Cou...    OH
# 4   [Wayne County, Lapeer County, Livingston Count...    MI
# ..                                                ...   ...
# 95  [Chatham County, Durham County, Orange County,...    NC
# 96  [Columbia County, Dane County, Green County, I...    WI
# 97                                   [Ventura County]    CA
# 98                  [Salt Lake County, Tooele County]    UT
# 99                         [Juab County, Utah County]    UT
#
# [100 rows x 5 columns]

# %%
# Split up each df so that each county has its own row. There may be some duplicates... take the average if this is the case
"""
def split(df):
    for i in range(len(df)):
        for j in range(len(df.loc[i, 'Counties'])):
                df['County'] = df.loc[i, 'Counties'][j]

def split_h(df):
     for i in range(1):
          for j in range(4):
               df['County'] = df.loc[i, 'Counties'][j]
     return df

split(two)
split_h(three)
# split(five)
three
"""
# Out:
# "\ndef split(df):\n    for i in range(len(df)):\n        for j in range(len(df.loc[i, 'Counties'])):\n                df['County'] = df.loc[i, 'Counties'][j]\n\ndef split_h(df):\n     for i in range(1):\n          for j in range(4):\n               df['County'] = df.loc[i, 'Counties'][j]\n     return df\n\nsplit(two)\nsplit_h(three)\n# split(five)\nthree\n"

# %%
print(len(three.loc[0, 'Counties']))
print(three.loc[0, 'Counties'])
print(three.loc[0, 'Counties'][0])
# Out:
# 4
# ['Warren County NJ', 'Carbon County PA', 'Lehigh County PA', 'Northampton County PA']
# Warren County NJ

# %%
# Split up each df so that each county has its own row. There may be some duplicates... take the average if this is the case

def split(df):
    # Add a column with empty strings for now
    df['County'] = ''
    # For every row in the dataframe
    for i in range(len(df)):
        for j in range(len(df.loc[i, 'Counties'])):
            # Create a new row at the end
            df.loc[len(df)] = [df.loc[i, 'Rank'], 
                            df.loc[i, 'Metropolitan_Area'],
                            df.loc[i, 'Score'],
                            df.loc[i, 'Counties'], 
                            df.loc[i, 'State'], 
                            #For the County column, take the jth item in the list
                            df.loc[i,'Counties'][j]
                            ]
    return df

split(three)

with pd.option_context("display.max_rows", 20):
    display(three)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[124], line 20
#      10             df.loc[len(df)] = [df.loc[i, 'Rank'],
#      11                             df.loc[i, 'Metropolitan_Area'],
#      12                             df.loc[i, 'Score'],
#    (...)     16                             df.loc[i,'Counties'][j]
#      17                             ]
#      18     return df
# ---> 20 split(three)
#      22 with pd.option_context("display.max_rows", 100):
#      23     display(three)
#
# Cell In[124], line 10, in split(df)
#       7 for i in range(len(df)):
#       8     for j in range(len(df.loc[i, 'Counties'])):
#       9         # Create a new row at the end
# ---> 10         df.loc[len(df)] = [df.loc[i, 'Rank'],
#      11                         df.loc[i, 'Metropolitan_Area'],
#      12                         df.loc[i, 'Score'],
#      13                         df.loc[i, 'Counties'],
#      14                         df.loc[i, 'State'],
#      15                         #For the County column, take the jth item in the list
#      16                         df.loc[i,'Counties'][j]
#      17                         ]
#      18 return df
#
# File ~/miniconda3/envs/ds6021/lib/python3.13/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/miniconda3/envs/ds6021/lib/python3.13/site-packages/pandas/core/indexing.py:1932, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1929     indexer, missing = convert_missing_indexer(indexer)
#    1931     if missing:
# -> 1932         self._setitem_with_indexer_missing(indexer, value)
#    1933         return
#    1935 if name == "loc":
#    1936     # must come after setting of missing
#
# File ~/miniconda3/envs/ds6021/lib/python3.13/site-packages/pandas/core/indexing.py:2328, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    2326     self.obj._mgr = df._mgr
#    2327 else:
# -> 2328     self.obj._mgr = self.obj._append(value)._mgr
#    2329 self.obj._maybe_update_cacher(clear=True)
#
# File ~/miniconda3/envs/ds6021/lib/python3.13/site-packages/pandas/core/frame.py:10579, in DataFrame._append(self, other, ignore_index, verify_integrity, sort)
#   10576 else:
#   10577     to_concat = [self, other]
# > 10579 result = concat(
#   10580     to_concat,
#   10581     ignore_index=ignore_index,
#   10582     verify_integrity=verify_integrity,
#   10583     sort=sort,
#   10584 )
#   10585 return result.__finalize__(self, method="append")
#
# File ~/miniconda3/envs/ds6021/lib/python3.13/site-packages/pandas/core/reshape/concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)    392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File ~/miniconda3/envs/ds6021/lib/python3.13/site-packages/pandas/core/reshape/concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File ~/miniconda3/envs/ds6021/lib/python3.13/site-packages/pandas/core/internals/concat.py:177, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     167 vals = [ju.block.values for ju in join_units]
#     169 if not blk.is_extension:
#     170     # _is_uniform_join_units ensures a single dtype, so
#     171     #  we can use np.concatenate, which is more performant
#    (...)    175     # expected "Union[_SupportsArray[dtype[Any]],
#     176     # _NestedSequence[_SupportsArray[dtype[Any]]]]"
# --> 177     values = np.concatenate(vals, axis=1)  # type: ignore[arg-type]
#     178 elif is_1d_only_ea_dtype(blk.dtype):
#     179     # TODO(EA2D): special-casing not needed with 2D EAs
#     180     values = concat_compat(vals, axis=0, ea_compat_axis=True)
#
# KeyboardInterrupt:
